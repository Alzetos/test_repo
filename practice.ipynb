# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy as sc
from sklearn.cluster import KMeans
import seaborn as sns

# %%
df = pd.read_csv("demand-forecasting-kernels-only/train.csv", encoding="utf-8")
print(df.describe())
print(df.info())
print(df.head(50))
# Out:
#                store           item          sales
# count  913000.000000  913000.000000  913000.000000
# mean        5.500000      25.500000      52.250287
# std         2.872283      14.430878      28.801144
# min         1.000000       1.000000       0.000000
# 25%         3.000000      13.000000      30.000000
# 50%         5.500000      25.500000      47.000000
# 75%         8.000000      38.000000      70.000000
# max        10.000000      50.000000     231.000000
# <class 'pandas.DataFrame'>
# RangeIndex: 913000 entries, 0 to 912999
# Data columns (total 4 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   date    913000 non-null  str
#  1   store   913000 non-null  int64
#  2   item    913000 non-null  int64
#  3   sales   913000 non-null  int64
# dtypes: int64(3), str(1)
# memory usage: 36.6 MB
# None
#           date  store  item  sales
# 0   2013-01-01      1     1     13
# 1   2013-01-02      1     1     11
# 2   2013-01-03      1     1     14
# 3   2013-01-04      1     1     13
# 4   2013-01-05      1     1     10
# 5   2013-01-06      1     1     12
# 6   2013-01-07      1     1     10
# 7   2013-01-08      1     1      9
# 8   2013-01-09      1     1     12
# 9   2013-01-10      1     1      9
# 10  2013-01-11      1     1      9
# 11  2013-01-12      1     1      7
# 12  2013-01-13      1     1     10
# 13  2013-01-14      1     1     12
# 14  2013-01-15      1     1      5
# 15  2013-01-16      1     1      7
# 16  2013-01-17      1     1     16
# 17  2013-01-18      1     1      7
# 18  2013-01-19      1     1     18
# 19  2013-01-20      1     1     15
# 20  2013-01-21      1     1      8
# 21  2013-01-22      1     1      7
# 22  2013-01-23      1     1      9
# 23  2013-01-24      1     1      8
# 24  2013-01-25      1     1     14
# 25  2013-01-26      1     1     12
# 26  2013-01-27      1     1     12
# 27  2013-01-28      1     1     11
# 28  2013-01-29      1     1      6
# 29  2013-01-30      1     1      9
# 30  2013-01-31      1     1     13
# 31  2013-02-01      1     1     11
# 32  2013-02-02      1     1     21
# 33  2013-02-03      1     1     15
# 34  2013-02-04      1     1     14
# 35  2013-02-05      1     1      9
# 36  2013-02-06      1     1     10
# 37  2013-02-07      1     1     13
# 38  2013-02-08      1     1     11
# 39  2013-02-09      1     1     14
# 40  2013-02-10      1     1     11
# 41  2013-02-11      1     1     16
# 42  2013-02-12      1     1     11
# 43  2013-02-13      1     1     14
# 44  2013-02-14      1     1     10
# 45  2013-02-15      1     1     11
# 46  2013-02-16      1     1      7
# 47  2013-02-17      1     1     11
# 48  2013-02-18      1     1     10
# 49  2013-02-19      1     1     10

# %%
df["day"] = pd.to_datetime(df["date"])
#df["day"] = df["day"].apply(lambda x: x.toordinal()) #от 1 дня нашей эры

df["day"] = (df["day"] - df["day"].min()).dt.days + 1 #от 0 дня в датасете
#print(df.info())

#df = df.dropna()

duplicates = df[df.duplicated(keep=False)]
#print(duplicates)

df["item"] = df["item"].interpolate(method="linear")

print(df.isna().sum())

"""kmeans = KMeans(n_clusters=10, random_state=0, n_init="auto")
kmeans.fit(df[["store"]])

print(kmeans.labels_, end="\n")
print(kmeans.cluster_centers_)"""

total_per_store = df.groupby("store")["sales"].sum().reset_index()
print(type(total_per_store))
print(df.head(10))
# Out:
# date     0
# store    0
# item     0
# sales    0
# day      0
# dtype: int64
# <class 'pandas.DataFrame'>
#          date  store  item  sales  day
# 0  2013-01-01      1     1     13    1
# 1  2013-01-02      1     1     11    2
# 2  2013-01-03      1     1     14    3
# 3  2013-01-04      1     1     13    4
# 4  2013-01-05      1     1     10    5
# 5  2013-01-06      1     1     12    6
# 6  2013-01-07      1     1     10    7
# 7  2013-01-08      1     1      9    8
# 8  2013-01-09      1     1     12    9
# 9  2013-01-10      1     1      9   10

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=total_per_store, x="shop", y="sales", palette="viridis")
plt.xlabel('Номер магазина', fontsize=12)
plt.ylabel('Сумма продаж', fontsize=12)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 figure = plt.scatter(total_per_store, label="", color="r")
#       2 plt.xlabel("axis date")
#       3 plt.ylabel("axis item")
#
# File c:\Users\0\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# TypeError: scatter() missing 1 required positional argument: 'y'
