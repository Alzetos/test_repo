# %%
from scipy import stats
import numpy as np

# %%
movie_table = np.array([40, 10],
                       [15,35])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 movie_table = np.matrix.shape(2,2)
#
# TypeError: 'getset_descriptor' object is not callable

# %%
battery_life = [12, 15, 14, 11, 24, 13, 14, 12, 28, 14]
statistics, p_value = stats.shapiro(battery_life)
if (p_value >= 0.05):
    print(f"Нормальное распредление")
else: 
    print(f"Нет нормального распределения")
print(f"p-value = {p_value}\n")
print(f"statistics = {statistics}")
# Out:
# Нет нормального распределения
# p-value = 0.0021252287277975686
#
# statistics = 0.7315041345989886
